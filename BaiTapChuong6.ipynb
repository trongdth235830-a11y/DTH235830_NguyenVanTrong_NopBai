# %%
print('Câu 1: Xử lý List')
from random import randrange 
 
print("Chương trình xử lý List") 
n=int(input("Nhập số phần tử")) 
lst=[0]*n 
for i in range(n): 
    lst[i]=randrange(-100,100) 
print("List ngẫu nhiên là:") 
print(lst) 
print("Mời bạn thêm số mới:") 
value=int(input()) 
lst.append(value) 
print(lst) 
print("bạn muốn đếm số nào:") 
k=int(input()) 
dem=lst.count(k) 
print(k,"xuất hiện ",dem,"trong list") 
def CheckPrime(n):
    d=0 
    for i in range(1,n+1): 
        if n%i ==0: 
            d+=1 
    return d==2 
demnt=0 
tongnt=0 
for x in lst: 
    if CheckPrime(x): 
        demnt+=1 
        tongnt+=x 
print("Có ",demnt,"số nguyên tố trong list") 
print("Tổng=",tongnt) 
lst.sort() 
print("List sau khi sort:") 
print(lst) 
 
del lst 
print("List sau khi xóa:")
# Out:
# Câu 1: Xử lý List
# Chương trình xử lý List
# List ngẫu nhiên là:
# [34, 11, 78, 70]
# Mời bạn thêm số mới:
# [34, 11, 78, 70, 60]
# bạn muốn đếm số nào:
# 70 xuất hiện  1 trong list
# Có  1 số nguyên tố trong list
# Tổng= 11
# List sau khi sort:
# [11, 34, 60, 70, 78]
# List sau khi xóa:

# %%
print('Câu 2: Xử lý List nhập ngẫu nhiên')
from random import randrange
lst = []
print("Nhập số phần tử:") 
n=int(input()) 
for i in range(n): 
    lst.append(randrange(0,100)) 
print("List sau khi tạo ngẫu nhiên là:") 
print(lst) 
x=int(input("Mời bạn chèn thêm số mới")) 
lst.append(x) 
print("List sau khi chèn:") 
print(lst) 
k=int(input("Mời nhập số để xóa")) 
while lst.count(k)>0: 
    lst.remove(k) 
print("List sau khi xóa:") 
print(lst) 
 
def CheckDoiXung(lst): 
    for i in range(len(lst)): 
        if lst[i]!=lst[len(lst)-i-1]: 
            return  False 
    return True 
kt=CheckDoiXung(lst) 
if kt==True: 
    print("List đối xứng") 
else: 
    print("List không đối xứng")
# Out:
# Câu 2: Xử lý List nhập ngẫu nhiên
# Nhập số phần tử:
# List sau khi tạo ngẫu nhiên là:
# [49, 44, 36]
# List sau khi chèn:
# [49, 44, 36, 23]
# List sau khi xóa:
# [44, 36, 23]
# List không đối xứng

# %%
print('Câu 3: Xử lý List Đa chiều')
from random import randrange 
 
def TaoMaTran(m, n): 
    D = [] 
    for i in range(m): 
        row = [] 
        for j in range(n): 
            row.append(randrange(100)) 
        D.append(row) 
    return D 

def XuatMaTran(D): 
    for row in D: 
        for element in row: 
            print(element, end='\t') 
        print() 

def LayDong(D, r): 
    return D[r] 

def XuatList1Chieu(R): 
    for element in R: 
        print(element, end='\t') 
    print()

def LayCot(D, c): 
    C = [] 
    for i in range(len(D)): 
        C.append(D[i][c]) 
    return C 

def MAX(D): 
    max_val = D[0][0] 
    for i in range(len(D)): 
        for j in range(len(D[i])): 
            if max_val < D[i][j]: 
                max_val = D[i][j] 
    return max_val

# Main chương trình
print("Nhập số dòng:") 
m = int(input()) 
print("Nhập số cột:") 
n = int(input()) 
D = TaoMaTran(m, n) 

print("\nMa trận ngẫu nhiên:")
XuatMaTran(D) 

print("Mời bạn nhập dòng muốn xuất:") 
r = int(input()) 
XuatList1Chieu(LayDong(D, r)) 

print("Mời bạn nhập cột muốn xuất:") 
c = int(input()) 
XuatList1Chieu(LayCot(D, c)) 

max_val = MAX(D) 
print("\nSố lớn nhất trong ma trận =", max_val)
# Out:
# Câu 3: Xử lý List Đa chiều
# Nhập số dòng:
# Nhập số cột:
#
# Ma trận ngẫu nhiên:
# 94	10	77
# 31	33	79
# 9	1	79
# Mời bạn nhập dòng muốn xuất:
# 9	1	79
# Mời bạn nhập cột muốn xuất:
# 77	79	79
#
# Số lớn nhất trong ma trận = 94

# %%
print('Câu 5: Xác định kết quả khi thực thi list')
lst = [20, 1, -34, 40, -8, 60, 1, 3]
print("a) lst =", lst)
print("b) lst[0:3] =", lst[0:3])
print("c) lst[4:8] =", lst[4:8])
print("d) lst[4:33] =", lst[4:33])
print("e) lst[-5:-3] =", lst[-5:-3])
print("f) lst[-22:3] =", lst[-22:3])
print("g) lst[4:] =", lst[4:])
print("h) lst[:] =", lst[:])
print("i) lst[:4] =", lst[:4])
print("j) lst[1:5] =", lst[1:5])
print("k) -34 in lst =", -34 in lst)
print("l) -34 not in lst =", -34 not in lst)
print("m) len(lst) =", len(lst))
# Out:
# Câu 5: Xác định kết quả khi thực thi list
# a) lst = [20, 1, -34, 40, -8, 60, 1, 3]
# b) lst[0:3] = [20, 1, -34]
# c) lst[4:8] = [-8, 60, 1, 3]
# d) lst[4:33] = [-8, 60, 1, 3]
# e) lst[-5:-3] = [40, -8]
# f) lst[-22:3] = [20, 1, -34]
# g) lst[4:] = [-8, 60, 1, 3]
# h) lst[:] = [20, 1, -34, 40, -8, 60, 1, 3]
# i) lst[:4] = [20, 1, -34, 40]
# j) lst[1:5] = [1, -34, 40, -8]
# k) -34 in lst = True
# l) -34 not in lst = False
# m) len(lst) = 8

# %%
print('Câu 6: Nhập vào 1 list có N số ngẫu nhiên KHÔNG TRÙNG NHAU')
from random import randrange
n = int(input("Nhập số phần tử N: "))
lst = []    
while len(lst) < n:
    num = randrange(0, 100)
    if num not in lst:
        lst.append(num)
print("List ngẫu nhiên không trùng nhau là:")
print(lst)
# Out:
# Câu 6: Nhập vào 1 list có N số ngẫu nhiên KHÔNG TRÙNG NHAU
# List ngẫu nhiên không trùng nhau là:
# [3, 66, 1, 77, 28]

# %%
print('Câu 7: Viết chương trình nhập vào một dãy các số theo thứ  tự tăng, nếu nhập sai' 
      'quy cách thì yêu cầu nhập lại. In dãy số sau khi đã nhập xong')
lst = []
n = int(input("Nhập số phần tử N: "))
for i in range(n):
    while True:
        num = int(input(f"Nhập số thứ {i+1}: "))
        if i == 0 or num > lst[i-1]:
            lst.append(num)
            break
        else:
            print("Số nhập vào không hợp lệ, vui lòng nhập lại.")
print("Dãy số sau khi nhập xong là:")
print(lst)
# Out:
# Câu 7: Viết chương trình nhập vào một dãy các số theo thứ  tự tăng, nếu nhập saiquy cách thì yêu cầu nhập lại. In dãy số sau khi đã nhập xong
# Số nhập vào không hợp lệ, vui lòng nhập lại.
# Dãy số sau khi nhập xong là:
# [2, 3, 5, 6, 7]

# %%
print(' Câu 8: Viết chương trình nhập vào một dãy n số thực M[0], M[1],..., M[n-1], sắp xếp'
    'dãy số theo thứ tự giảm dần. Xuất ra dãy số sau khi sắp xếp. ')
n = int(input("Nhập số phần tử N: "))
M = []
for i in range(n):
    num = int(input(f"Nhập số thứ {i+1}: "))
    M.append(num)
M.sort(reverse=True)
print("Dãy số sau khi sắp xếp giảm dần là:")
print(M)
# Out:
#  Câu 8: Viết chương trình nhập vào một dãy n số thực M[0], M[1],..., M[n-1], sắp xếpdãy số theo thứ tự giảm dần. Xuất ra dãy số sau khi sắp xếp.
# Dãy số sau khi sắp xếp giảm dần là:
# [7, 6, 4, 3, 2, 2]

# %%
print('Câu 9: Xử lý mảng')
lst=[]
n=int(input("Nhập số phần tử N:"))
for i in range(n):
    num=int(input(f"Nhập số thứ {i+1}:"))
    lst.append(num)
print("Mảng vừa nhập là:")
print(lst)
def is_prime(n):
    if n < 2:
        return False
    for i in range(2, int(n**0.5)+1):
        if n % i == 0:
            return False
    return True
so_le = []
so_chan = []
so_nguyen_to = []
so_khong_nguyen_to = []
for x in M:
    if x % 2 == 1:
        so_le.append(x)
    else:
        so_chan.append(x)
    
    if is_prime(x):
        so_nguyen_to.append(x)
    else:
        so_khong_nguyen_to.append(x)

# sole
print("Các số lẻ:", ', '.join(map(str, so_le)), f"➔ {len(so_le)} số lẻ")

# sochan
print("Các số chẵn:", ', '.join(map(str, so_chan)), f"➔ {len(so_chan)} số chẵn")

# snt
print("Các số nguyên tố:", ', '.join(map(str, so_nguyen_to)))

# not_snt
print("Các số không phải là số nguyên tố:", ', '.join(map(str, so_khong_nguyen_to)))
# Out:
# Câu 9: Xử lý mảng
# Mảng vừa nhập là:
# [3, 5, 2, 33, 26, 6, 3, 4, 1]
# Các số lẻ: 7, 3 ➔ 2 số lẻ
# Các số chẵn: 6, 4, 2, 2 ➔ 4 số chẵn
# Các số nguyên tố: 7, 3, 2, 2
# Các số không phải là số nguyên tố: 6, 4

# %%
print('Câu 10: Xử lý Ma Trận')

def nhap_ma_tran(m, n):
    mat = []
    for i in range(m):
        row = []
        for j in range(n):
            row.append(int(input(f"Nhập phần tử hàng {i}, cột {j}: ")))
        mat.append(row)
    return mat

def xuat_ma_tran(mat):
    for row in mat:
        for val in row:
            print(val, end='\t')
        print()

def cong_ma_tran(A, B):
    m = len(A)
    n = len(A[0])
    C = []
    for i in range(m):
        row = []
        for j in range(n):
            row.append(A[i][j] + B[i][j])
        C.append(row)
    return C

def hoan_vi_ma_tran(M):
    m = len(M)
    n = len(M[0])
    H = []
    for j in range(n):
        row = []
        for i in range(m):
            row.append(M[i][j])
        H.append(row)
    return H

m = int(input("Nhập số dòng: "))
n = int(input("Nhập số cột: "))

print("Nhập ma trận A:")
A = nhap_ma_tran(m, n)

print("Nhập ma trận B:")
B = nhap_ma_tran(m, n)

print("Ma trận A:")
xuat_ma_tran(A)

print("Ma trận B:")
xuat_ma_tran(B)

print("Tổng A + B:")
C = cong_ma_tran(A, B)
xuat_ma_tran(C)

print("Hoán vị của A:")
HA = hoan_vi_ma_tran(A)
xuat_ma_tran(HA)

print("Hoán vị của B:")
HB = hoan_vi_ma_tran(B)
xuat_ma_tran(HB)
# Out:
# Câu 10: Xử lý Ma Trận
# Nhập ma trận A:
# Nhập ma trận B:
# Ma trận A:
# 1	2	3
# 4	5	6
# Ma trận B:
# 7	8	9
# 2	3	1
# Tổng A + B:
# 8	10	12
# 6	8	7
# Hoán vị của A:
# 1	4
# 2	5
# 3	6
# Hoán vị của B:
# 7	2
# 8	3
# 9	1
